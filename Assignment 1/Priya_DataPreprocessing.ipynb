# %%
import pandas as pd

# %%
# reads csv files in data frames
DataSet1=pd.read_csv("FirstSetQueryResults.csv")
DataSet2=pd.read_csv("SecondSetQueryResults.csv")
DataSet3=pd.read_csv("ThirdSetQueryResults.csv")
DataSet4=pd.read_csv("FourthSetQueryResults.csv")

# %%
# removes html tags
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup

# %%
# function to remove html tags
def removetags(raw_data):
    cleandata=BeautifulSoup(raw_data, "lxml").text
    return cleandata

# %%
# data frame before removing html tags
DataSet1.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0    927358           1          927386.0       NaN  2009-05-29 18:09:14
# 1   2003505           1         2003515.0       NaN  2010-01-05 01:12:15
# 2   5767325           1         5767357.0       NaN  2011-04-23 22:17:18
# 3  16956810           1        16957078.0       NaN  2013-06-06 08:06:45
# 4   2906582           1         2906586.0       NaN  2010-05-25 16:39:47
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN  23303   10030841
# 1           NaN  18475    9258686
# 2           NaN   9899    8897394
# 3           NaN   6286    8203000
# 4           NaN   2298    7782563
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>I accidentally <strong>committed the wrong ...      89904.0  ...
# 1  <p>I want to delete a branch both locally and ...      95592.0  ...
# 2  <p>I have an array of numbers and I'm using th...     364969.0  ...
# ...

# %%
# removing html tags from body column
DataSet1["Body"]=DataSet1["Body"].apply(removetags)
DataSet1.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0    927358           1          927386.0       NaN  2009-05-29 18:09:14
# 1   2003505           1         2003515.0       NaN  2010-01-05 01:12:15
# 2   5767325           1         5767357.0       NaN  2011-04-23 22:17:18
# 3  16956810           1        16957078.0       NaN  2013-06-06 08:06:45
# 4   2906582           1         2906586.0       NaN  2010-05-25 16:39:47
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN  23303   10030841
# 1           NaN  18475    9258686
# 2           NaN   9899    8897394
# 3           NaN   6286    8203000
# 4           NaN   2298    7782563
#
#                                                 Body  OwnerUserId  ...  \
# 0  I accidentally committed the wrong files to Gi...      89904.0  ...
# 1  I want to delete a branch both locally and rem...      95592.0  ...
# 2  I have an array of numbers and I'm using the ....     364969.0  ...
# ...

# %%
DataSet2["Body"]=DataSet2["Body"].apply(removetags)
DataSet2.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0  47772157           1        47793764.0       NaN  2017-12-12 12:01:59
# 1  37306672           1               NaN       NaN  2016-05-18 17:39:46
# 2  22700728           1        41141129.0       NaN  2014-03-27 22:39:46
# 3     70272           1           70296.0       NaN  2008-09-16 08:10:53
# 4   2643462           1         2643598.0       NaN  2010-04-15 07:39:40
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN     50     127400
# 1           NaN     97     127397
# 2           NaN     78     127395
# 3           NaN     77     127392
# 4           NaN     23     127391
#
#                                                 Body  OwnerUserId  ...  \
# 0  I'm on a windows machine without admin right a...    2344958.0  ...
# 1  Just installed Visual Studio Code 1.1.1 on a W...    1864541.0  ...
# 2  i ran in a problem using composer for installi...    1315408.0  ...
# ...

# %%
DataSet3["Body"]=DataSet3["Body"].apply(removetags)
DataSet3.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0  26486696           1        26486817.0       NaN  2014-10-21 12:25:42
# 1  49422588           1               NaN       NaN  2018-03-22 07:12:04
# 2  25275202           1        25275336.0       NaN  2014-08-12 22:35:02
# 3   1143841           1         1143994.0       NaN  2009-07-17 15:03:52
# 4   2940671           1         2940700.0       NaN  2010-05-30 23:04:12
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN     22      52801
# 1           NaN     78      52801
# 2           NaN      1      52801
# 3           NaN     36      52801
# 4           NaN     66      52801
#
#                                                 Body  OwnerUserId  ...  \
# 0  I have following text input filled by model va...     535556.0  ...
# 1  AADSTS70005: response_type 'id_token' is not e...    8913221.0  ...
# 2  I have a column in a table with a varchar data...    1408809.0  ...
# ...

# %%
DataSet4["Body"]=DataSet4["Body"].apply(removetags)
DataSet4.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0  56507839           1        67888605.0       NaN  2019-06-08 15:44:30
# 1    974680           1         1417817.0       NaN  2009-06-10 10:02:40
# 2   3630704           1         3631386.0       NaN  2010-09-02 19:54:48
# 3  31675192           1        31693357.0       NaN  2015-07-28 11:37:08
# 4  31305809           1               NaN       NaN  2015-07-08 23:51:42
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN    114      53204
# 1           NaN     13      53204
# 2           NaN      7      53204
# 3           NaN     12      53204
# 4           NaN      4      53203
#
#                                                 Body  OwnerUserId  ...  \
# 0  Here's my SwiftUI code:\nstruct ContentView : ...       6583.0  ...
# 1  I would like to create a photo/video capture a...      22996.0  ...
# 2  Does VBA support using an array of range varia...     438322.0  ...
# ...

# %%
import re
import string

# %%
# function to remove punctuation
def removepuctuations(data):
    pattern = r'[' + string.punctuation + ']'
    return re.sub(pattern, '', data)

# %%
# removing punctuations from body column
DataSet1["Body"]=DataSet1["Body"].apply(removepuctuations)
DataSet2["Body"]=DataSet2["Body"].apply(removepuctuations)
DataSet3["Body"]=DataSet3["Body"].apply(removepuctuations)
DataSet4["Body"]=DataSet4["Body"].apply(removepuctuations)

# %%
# removing punctuations from title column
DataSet1["Title"]=DataSet1["Title"].apply(removepuctuations)
DataSet2["Title"]=DataSet2["Title"].apply(removepuctuations)
DataSet3["Title"]=DataSet3["Title"].apply(removepuctuations)
DataSet4["Title"]=DataSet4["Title"].apply(removepuctuations)

# %%
DataSet1 = DataSet1.replace(r'\n',' ', regex=True) 
DataSet1 = DataSet1.replace(r'\t',' ', regex=True)
DataSet1 = DataSet1.replace(r'\r',' ', regex=True)
DataSet1 = DataSet1.replace(r'\b',' ', regex=True)
DataSet1 = DataSet1.replace(r'\f',' ', regex=True)

DataSet2 = DataSet2.replace(r'\n',' ', regex=True) 
DataSet2 = DataSet2.replace(r'\t',' ', regex=True)
DataSet2 = DataSet2.replace(r'\r',' ', regex=True)
DataSet2 = DataSet2.replace(r'\b',' ', regex=True)
DataSet2 = DataSet2.replace(r'\f',' ', regex=True)

DataSet3 = DataSet3.replace(r'\n',' ', regex=True) 
DataSet3 = DataSet3.replace(r'\t',' ', regex=True)
DataSet3 = DataSet3.replace(r'\r',' ', regex=True)
DataSet3 = DataSet3.replace(r'\b',' ', regex=True)
DataSet3 = DataSet3.replace(r'\f',' ', regex=True)

DataSet4 = DataSet4.replace(r'\n',' ', regex=True) 
DataSet4 = DataSet4.replace(r'\t',' ', regex=True)
DataSet4 = DataSet4.replace(r'\r',' ', regex=True)
DataSet4 = DataSet4.replace(r'\b',' ', regex=True)
DataSet4 = DataSet4.replace(r'\f',' ', regex=True)

# %%
# merged all 4 files using concat
MergedData = pd.concat([DataSet1,DataSet2,DataSet3,DataSet4])

# %%
MergedData.shape
# Out:
# (200000, 23)

# %%
# exporting processed file in .csv
MergedData.to_csv("preprocessedMergedData.csv")

# %%
# exporting processed files in .txt
MergedData.to_csv("preprocessedMergedData.txt")
